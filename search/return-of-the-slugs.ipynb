# %%
class Cell:
    def __init__(self, x: int, y: int) -> None:
        self.x = x
        self.y = y

    def __str__(self) -> str:
        return f"Cell(x={self.x}, y={self.y}))"

    def __eq__(self, __value: object) -> bool:
        if not isinstance(__value, Cell) or __value is None:
            return False

        return self.x == __value.x and self.y == __value.y

    def __add__(self, __value: "Cell"):
        return Cell(self.x + __value.x, self.y + __value.y)

    def __sub__(self, __value: "Cell"):
        return Cell(self.x - __value.x, self.y - __value.y)

    @property
    def is_within_boundaries(self):
        return 0 <= self.x <= 7 and 0 <= self.y <= 5

# %%
from typing import NamedTuple, Union

POISONOUS_CELL = Union[Cell, None]


class MazeState(NamedTuple):
    slug_1: Cell
    slug_2: Cell
    poison_1: POISONOUS_CELL
    poison_2: POISONOUS_CELL
    poison_3: POISONOUS_CELL
    poison_4: POISONOUS_CELL

    def __str__(self) -> str:
        return f"MazeState(slug_1={self.slug_1}, slug_2={self.slug_2}, poison_1={self.poison_1}, poison_2={self.poison_2}, poison_3={self.poison_3}, poison_4={self.poison_4})"

    def __eq__(self, __value: "MazeState") -> bool:
        return self.slug_1 == __value.slug_1 and self.slug_2 == __value.slug_2

    @staticmethod
    def with_initial_state(s1: Cell, s2: Cell) -> "MazeState":
        return MazeState(s1, s2, None, None, None, None)

    def with_poisonous_cells(self, s1: Cell, s2: Cell, timestep: int) -> "MazeState":
        if timestep != 0 and timestep % 2 == 0:
            return MazeState(
                s1,
                s2,
                poison_1=self.poison_1,
                poison_2=None,
                poison_3=self.poison_3,
                poison_4=None,
            )

        return MazeState(
            s1,
            s2,
            poison_1=self.slug_1,
            poison_2=self.poison_1,
            poison_3=self.slug_2,
            poison_4=self.poison_3,
        )

# %%
class Node:
    def __init__(
        self, state: MazeState, parent: Union["Node", None], action: str
    ) -> None:
        self.state = state
        self.parent = parent
        self.action = action

# %%
from abc import ABC, abstractmethod


class Frontier(ABC):
    @abstractmethod
    def is_empty(self) -> bool:
        pass

    @abstractmethod
    def add_node(self, node: Node) -> None:
        pass

    @abstractmethod
    def remove_node(self) -> Node:
        pass

    @abstractmethod
    def has_state(self, state: MazeState) -> bool:
        pass


class StackFrontier(Frontier):
    def __init__(self) -> None:
        self.frontier: list[Node] = []

    @property
    def is_empty(self) -> bool:
        return len(self.frontier) == 0

    def add_node(self, node: Node) -> None:
        self.frontier.append(node)

    def remove_node(self) -> Node:
        if self.is_empty:
            raise Exception("Empty frontier")
        else:
            return self.frontier.pop()

    def has_state(self, state: MazeState) -> bool:
        return any(state == n.state for n in self.frontier)


class QueueFrontier(StackFrontier):
    def remove_node(self) -> Node:
        if self.is_empty:
            raise Exception("Empty frontier")
        else:
            return self.frontier.pop(0)

# %%
CANDIDATE_ACTION = tuple[str, MazeState]


def create_candidates(state: MazeState, timestep: int):
    slug1, slug2, poison1, _, poison3, _ = state

    candidates: list[CANDIDATE_ACTION] = [
        # They move in the same direction
        (
            "Both slugs moves up",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1), slug2 + Cell(0, 1), timestep=timestep
            ),
        ),
        (
            "Both slugs moves down",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1), slug2 + Cell(0, -1), timestep=timestep
            ),
        ),
        (
            "Both slugs moves left",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0), slug2 + Cell(-1, 0), timestep=timestep
            ),
        ),
        (
            "Both slugs moves right",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0), slug2 + Cell(1, 0), timestep=timestep
            ),
        ),
        # They move in opposite directions
        # Slug 1 up
        (
            "Slug 1 moves up, slug 2 moves left",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1), slug2 + Cell(-1, 0), timestep=timestep
            ),
        ),
        (
            "Slug 1 moves up, slug 2 moves right",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1), slug2 + Cell(1, 0), timestep=timestep
            ),
        ),
        # Slug 1 down
        (
            "Slug 1 moves down, slug 2 moves left",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1), slug2 + Cell(-1, 0), timestep=timestep
            ),
        ),
        (
            "Slug 1 moves down, slug 2 moves right",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1), slug2 + Cell(1, 0), timestep=timestep
            ),
        ),
        # Slug 1 left
        (
            "Slug 1 moves left, slug 2 moves up",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0), slug2 + Cell(0, 1), timestep=timestep
            ),
        ),
        (
            "Slug 1 moves left, slug 2 moves down",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0), slug2 + Cell(0, -1), timestep=timestep
            ),
        ),
        # Slug 1 right
        (
            "Slug 1 moves right, slug 2 moves up",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0), slug2 + Cell(0, 1), timestep=timestep
            ),
        ),
        (
            "Slug 1 moves right, slug 2 moves down",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0), slug2 + Cell(0, -1), timestep=timestep
            ),
        ),
    ]

    return candidates

# %%
class SlugMaze:
    def __init__(
        self, initial_state: MazeState, goal_state: MazeState, wall: list[Cell]
    ) -> None:
        self.initial_state = initial_state
        self.goal_state = goal_state
        self.wall = wall

        self.solution: Union[list[CANDIDATE_ACTION], None] = None
        self.timestep = 0

    def __str__(self) -> str:
        return f"SlugMaze(initial_state={self.initial_state}, goal_state={self.goal_state}, wall={self.wall}, solution={self.solution})"

    def neighbors(self, state: MazeState, previous_action: str, goal: MazeState):
        # goal_slug1, goal_slug2, _, _, _, _ = goal

        candidates: list[CANDIDATE_ACTION] = create_candidates(state, self.timestep)
        self.timestep += 1
        result: list[CANDIDATE_ACTION] = []

        for action, candidate in candidates:
            slug1, slug2, poison1, poison2, poison3, poison4 = candidate
            poisonous_cells = [poison1, poison2, poison3, poison4]

            if (
                slug1 not in self.wall
                and slug2 not in self.wall
                and slug1 not in poisonous_cells
                and slug2 not in poisonous_cells
            ):  # not heading into bad cells
                if (
                    slug1.is_within_boundaries
                    and slug2.is_within_boundaries
                    and action != previous_action
                ):  # ensure we're still on the board
                    result.append((action, candidate))

        return result

    def solve(self, frontier: StackFrontier) -> None:
        self.num_explored = 0

        start = Node(state=self.initial_state, parent=None, action="None")
        frontier.add_node(start)

        self.explored: list[MazeState] = []

        while True:
            if frontier.is_empty:
                raise Exception("No solution")

            node = frontier.remove_node()
            self.num_explored += 1

            print(f"{self.num_explored} - {node.state}\n")

            if node.state == self.goal_state:
                actions = []
                cells = []
                while node.parent is not None:
                    actions.append(node.action)
                    cells.append(node.state)
                    node = node.parent
                actions.reverse()
                cells.reverse()
                self.solution = list(zip(actions, cells))
                return

            self.explored.append(node.state)

            for action, state in self.neighbors(
                node.state, node.action, self.goal_state
            ):
                if state not in self.explored and not frontier.has_state(state):
                    child = Node(state=state, parent=node, action=action)
                    frontier.add_node(child)

# %%
wall: list[Cell] = [Cell(3, 0), Cell(3, 1), Cell(
    3, 2), Cell(4, 2), Cell(2, 2)]

goal_state = MazeState(
    slug_1=Cell(4, 0),
    slug_2=Cell(6, 0),
    poison_1=None,
    poison_2=None,
    poison_3=None,
    poison_4=None,
)

with_initial_state = MazeState.with_initial_state(s1=Cell(0, 0), s2=Cell(0, 4))
maze = SlugMaze(initial_state=with_initial_state,
                goal_state=goal_state, wall=wall)
stack_frontier = StackFrontier()
maze.solve(stack_frontier)
# Out:
# 1 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=0, y=4)), poison_1=None, poison_2=None, poison_3=None, poison_4=None)
#
# 2 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 3 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=0, y=4)))
#
# 4 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=0, y=3)), poison_4=None)
#
# 5 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=2, y=1)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=0, y=3)))
#
# 6 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=2, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 7 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=1)), poison_4=Cell(x=1, y=2)))
#
# 8 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=1)), poison_4=Cell(x=1, y=2)))
#
# 9 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=1)), poison_4=Cell(x=1, y=2)))
#
# 10 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=2, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 11 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=1)), poison_4=Cell(x=1, y=2)))
#
# 12 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=0, y=1)), poison_2=None, poison_3=Cell(x=0, y=1)), poison_4=None)
#
# 13 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=1)), poison_3=Cell(x=1, y=0)), poison_4=Cell(x=0, y=1)))
#
# 14 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=1, y=0)), poison_4=None)
#
# 15 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=2, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=1)), poison_4=Cell(x=1, y=0)))
#
# 16 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=1, y=0)), poison_4=None)
#
# 17 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=1)), poison_4=Cell(x=1, y=0)))
#
# 18 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=1)), poison_3=Cell(x=1, y=0)), poison_4=Cell(x=0, y=1)))
#
# 19 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=0, y=0)), poison_4=Cell(x=1, y=0)))
#
# 20 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=0, y=0)), poison_4=None)
#
# 21 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=0, y=0)))
#
# 22 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=2, y=4)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 23 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=1, y=1)))
#
# 24 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=2, y=0)), poison_4=None)
#
# 25 - MazeState(slug_1=Cell(x=5, y=4)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=2, y=0)))
#
# 26 - MazeState(slug_1=Cell(x=5, y=3)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=4, y=4)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 27 - MazeState(slug_1=Cell(x=6, y=3)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=5, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=1, y=1)))
#
# 28 - MazeState(slug_1=Cell(x=6, y=2)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=2, y=0)), poison_4=None)
#
# 29 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=2, y=0)))
#
# 30 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=6, y=2)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 31 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=1, y=1)))
#
# 32 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=2, y=0)), poison_4=None)
#
# 33 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=2, y=0)))
#
# 34 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 35 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=1)))
#
# 36 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 37 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=2)))
#
# 38 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 39 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=3)))
#
# 40 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 41 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=2, y=4)))
#
# 42 - MazeState(slug_1=Cell(x=5, y=1)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 43 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=5)))
#
# 44 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 45 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=4)))
#
# 46 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 47 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=5, y=3)))
#
# 48 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=6, y=2)), poison_4=None)
#
# 49 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=6, y=2)))
#
# 50 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=4, y=0)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=5, y=1)), poison_4=None)
#
# 51 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=4, y=0)), poison_4=Cell(x=5, y=1)))
#
# 52 - MazeState(slug_1=Cell(x=6, y=2)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=4, y=0)), poison_4=None)
#
# 53 - MazeState(slug_1=Cell(x=5, y=2)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=0)))
#
# 54 - MazeState(slug_1=Cell(x=5, y=3)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=6, y=2)), poison_2=None, poison_3=Cell(x=5, y=1)), poison_4=None)
#
# 55 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=5, y=3)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=5, y=1)))
#
# 56 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=6, y=0)), poison_4=None)
#
# 57 - MazeState(slug_1=Cell(x=5, y=4)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=0)))
#
# 58 - MazeState(slug_1=Cell(x=5, y=5)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=4, y=4)), poison_2=None, poison_3=Cell(x=7, y=1)), poison_4=None)
#
# 59 - MazeState(slug_1=Cell(x=6, y=5)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=5, y=5)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=7, y=1)))
#
# 60 - MazeState(slug_1=Cell(x=6, y=4)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=5, y=5)), poison_2=None, poison_3=Cell(x=6, y=0)), poison_4=None)
#
# 61 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=6, y=4)), poison_2=Cell(x=5, y=5)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=0)))
#
# 62 - MazeState(slug_1=Cell(x=7, y=3)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=6, y=4)), poison_2=None, poison_3=Cell(x=7, y=1)), poison_4=None)
#
# 63 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=6, y=4)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=7, y=1)))
#
# 64 - MazeState(slug_1=Cell(x=6, y=2)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=7, y=3)), poison_2=None, poison_3=Cell(x=6, y=0)), poison_4=None)
#
# 65 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=7, y=2)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=7, y=3)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=0)))
#
# 66 - MazeState(slug_1=Cell(x=7, y=3)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=6, y=2)), poison_2=None, poison_3=Cell(x=7, y=1)), poison_4=None)
#
# 67 - MazeState(slug_1=Cell(x=6, y=3)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=7, y=3)), poison_4=Cell(x=7, y=1)))
#
# 68 - MazeState(slug_1=Cell(x=6, y=2)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=7, y=3)), poison_2=None, poison_3=Cell(x=7, y=3)), poison_4=None)
#
# 69 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=7, y=3)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=7, y=3)))
#
# 70 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=6, y=2)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 71 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=7, y=5)), poison_4=Cell(x=6, y=4)))
#
# 72 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=7, y=1)), poison_2=None, poison_3=Cell(x=7, y=5)), poison_4=None)
#
# 73 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=7, y=1)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=7, y=5)))
#
# 74 - MazeState(slug_1=Cell(x=5, y=1)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 75 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=7, y=5)), poison_4=Cell(x=6, y=4)))
#
# 76 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=7, y=5)), poison_4=None)
#
# 77 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=4, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=7, y=5)))
#
# 78 - MazeState(slug_1=Cell(x=5, y=1)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=4, y=0)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 79 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=7, y=2)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=4, y=0)), poison_3=Cell(x=7, y=3)), poison_4=Cell(x=6, y=4)))
#
# 80 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=7, y=3)), poison_4=None)
#
# 81 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=7, y=3)))
#
# 82 - MazeState(slug_1=Cell(x=5, y=1)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=6, y=0)), poison_2=None, poison_3=Cell(x=6, y=2)), poison_4=None)
#
# 83 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=6, y=0)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=2)))
#
# 84 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=7, y=1)), poison_4=None)

# %%
queue_frontier = QueueFrontier()
maze.solve(queue_frontier)
# Out:
# 1 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=0, y=4)), poison_1=None, poison_2=None, poison_3=None, poison_4=None)
#
# 2 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 3 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 4 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 5 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 6 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 7 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 8 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 9 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=4)))
#
# 10 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=4)))
#
# 11 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=4)))
#
# 12 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 13 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=4)))
#
# 14 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=4)))
#
# 15 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=4)))
#
# 16 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=4)))
#
# 17 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 18 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 19 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 20 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 21 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 22 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 23 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 24 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 25 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=2, y=0)), poison_2=Cell(x=1, y=0)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=1, y=4)))
#
# 26 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 27 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 28 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 29 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 30 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 31 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 32 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=0, y=5)), poison_4=Cell(x=1, y=5)))
#
# 33 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=1, y=5)), poison_4=None)
#
# 34 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=1, y=5)))
#
# 35 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=1, y=5)))
#
# 36 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=1, y=5)))
#
# 37 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=1, y=5)), poison_4=None)
#
# 38 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=0, y=5)), poison_4=Cell(x=0, y=4)))
#
# 39 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 40 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 41 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=4)))
#
# 42 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=4)))
#
# 43 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 44 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 45 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=3)), poison_4=Cell(x=2, y=4)))
#
# 46 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=3)), poison_4=Cell(x=2, y=4)))
#
# 47 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=3)), poison_4=Cell(x=2, y=4)))
#
# 48 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 49 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=2, y=1)), poison_2=Cell(x=2, y=0)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=1, y=3)))
#
# 50 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 51 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 52 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 53 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=2, y=3)), poison_4=Cell(x=0, y=4)))
#
# 54 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=0, y=4)))
#
# 55 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 56 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=5)))
#
# 57 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=5)))
#
# 58 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=5)))
#
# 59 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=5)))
#
# 60 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 61 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 62 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 63 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=0, y=4)))
#
# 64 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=0, y=4)))
#
# 65 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=0, y=4)))
#
# 66 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 67 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 68 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 69 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 70 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 71 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 72 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=2, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=3, y=3)), poison_4=Cell(x=2, y=4)))
#
# 73 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 74 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 75 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=0, y=1)), poison_3=Cell(x=3, y=3)), poison_4=Cell(x=2, y=3)))
#
# 76 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=0, y=3)))
#
# 77 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=0, y=3)))
#
# 78 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 79 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 80 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 81 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 82 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=4)))
#
# 83 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=4)))
#
# 84 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=4)))
#
# 85 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=4)))
#
# 86 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 87 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 88 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=0, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 89 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=5)))
#
# 90 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=0, y=5)))
#
# 91 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 92 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 93 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=2, y=4)))
#
# 94 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=2, y=4)))
#
# 95 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 96 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 97 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=0, y=5)))
#
# 98 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=0, y=5)))
#
# 99 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=0, y=5)))
#
# 100 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=0, y=5)))
#
# 101 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 102 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 103 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 104 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 105 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 106 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 107 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=4, y=5)), poison_4=Cell(x=3, y=5)))
#
# 108 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 109 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 110 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=2, y=4)))
#
# 111 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=2, y=4)))
#
# 112 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 113 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=1, y=4)))
#
# 114 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=1, y=4)))
#
# 115 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=2, y=1)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=2, y=4)))
#
# 116 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=2, y=1)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=2, y=4)))
#
# 117 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=4, y=3)), poison_4=Cell(x=3, y=3)))
#
# 118 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=4, y=3)), poison_4=Cell(x=3, y=3)))
#
# 119 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 120 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 121 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 122 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 123 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 124 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 125 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 126 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=1, y=3)))
#
# 127 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=0, y=3)), poison_4=Cell(x=1, y=3)))
#
# 128 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 129 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=1, y=2)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=0, y=1)), poison_4=Cell(x=0, y=4)))
#
# 130 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=0, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 131 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=0, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 132 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=1, y=4)))
#
# 133 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=1, y=4)))
#
# 134 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=2, y=4)))
#
# 135 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 136 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 137 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 138 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 139 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 140 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 141 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=3, y=4)), poison_4=None)
#
# 142 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=3, y=3)), poison_4=Cell(x=2, y=4)))
#
# 143 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=3, y=3)), poison_4=Cell(x=2, y=4)))
#
# 144 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 145 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=3, y=5)), poison_4=Cell(x=2, y=5)))
#
# 146 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=2, y=5)))
#
# 147 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=5)))
#
# 148 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=5)))
#
# 149 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=5)))
#
# 150 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=0, y=5)))
#
# 151 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=0, y=5)))
#
# 152 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 153 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=5)), poison_4=Cell(x=0, y=5)))
#
# 154 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 155 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 156 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 157 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 158 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 159 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 160 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=5, y=5)), poison_4=Cell(x=0, y=4)))
#
# 161 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=2, y=3)), poison_2=None, poison_3=Cell(x=3, y=4)), poison_4=None)
#
# 162 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=3, y=3)), poison_4=Cell(x=3, y=4)))
#
# 163 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 164 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=3)))
#
# 165 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=0, y=3)))
#
# 166 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=2, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=5, y=4)))
#
# 167 - MazeState(slug_1=Cell(x=1, y=0)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=2, y=1)), poison_2=None, poison_3=Cell(x=5, y=4)), poison_4=None)
#
# 168 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=3)))
#
# 169 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=3)))
#
# 170 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=3)))
#
# 171 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=3)))
#
# 172 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 173 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 174 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 175 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=0, y=0)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=0, y=0)), poison_4=Cell(x=0, y=2)))
#
# 176 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 177 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=0, y=4)))
#
# 178 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=0, y=4)))
#
# 179 - MazeState(slug_1=Cell(x=0, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=1)), poison_2=Cell(x=0, y=0)), poison_3=Cell(x=2, y=0)), poison_4=Cell(x=0, y=4)))
#
# 180 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 181 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 182 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 183 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=1, y=5)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=3)))
#
# 184 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=1, y=5)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=3)))
#
# 185 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=1, y=4)), poison_2=None, poison_3=Cell(x=0, y=3)), poison_4=None)
#
# 186 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=0, y=3)))
#
# 187 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=0, y=3)))
#
# 188 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=0, y=3)))
#
# 189 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 190 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 191 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=0, y=1)))
#
# 192 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=0, y=1)))
#
# 193 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=0, y=1)))
#
# 194 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 195 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 196 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 197 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=4, y=5)), poison_4=Cell(x=2, y=4)))
#
# 198 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=0, y=2)), poison_3=Cell(x=4, y=5)), poison_4=Cell(x=2, y=4)))
#
# 199 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 200 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 201 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=4, y=4)))
#
# 202 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=4, y=4)))
#
# 203 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=4, y=4)))
#
# 204 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 205 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 206 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 207 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 208 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=4, y=3)), poison_4=Cell(x=3, y=4)))
#
# 209 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 210 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 211 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=3, y=5)))
#
# 212 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=3, y=5)))
#
# 213 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=0, y=4)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 214 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=2, y=5)), poison_4=Cell(x=1, y=5)))
#
# 215 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 216 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 217 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 218 - MazeState(slug_1=Cell(x=5, y=3)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 219 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 220 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=3, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 221 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=2, y=3)), poison_4=Cell(x=2, y=4)))
#
# 222 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 223 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 224 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 225 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=1, y=5)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 226 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=1, y=3)), poison_1=Cell(x=0, y=3)), poison_2=None, poison_3=Cell(x=0, y=5)), poison_4=None)
#
# 227 - MazeState(slug_1=Cell(x=5, y=3)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 228 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=0, y=4)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 229 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=2, y=4)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=1, y=4)), poison_4=Cell(x=1, y=5)))
#
# 230 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 231 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=0, y=3)), poison_2=Cell(x=1, y=1)), poison_3=Cell(x=5, y=4)), poison_4=Cell(x=3, y=5)))
#
# 232 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=0, y=0)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 233 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=5, y=5)), poison_4=None)
#
# 234 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=5, y=5)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=4, y=5)), poison_4=Cell(x=3, y=4)))
#
# 235 - MazeState(slug_1=Cell(x=5, y=3)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=4, y=3)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=4, y=5)), poison_4=Cell(x=3, y=4)))
#
# 236 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=5, y=3)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=3, y=3)), poison_4=None)
#
# 237 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=0, y=2)), poison_1=Cell(x=1, y=4)), poison_2=Cell(x=0, y=4)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=1, y=3)))
#
# 238 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=2, y=0)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 239 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=4)))
#
# 240 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=4)))
#
# 241 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=1, y=0)), poison_2=Cell(x=2, y=1)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=4)))
#
# 242 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 243 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=3)))
#
# 244 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=3)))
#
# 245 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=6, y=3)), poison_4=Cell(x=5, y=3)))
#
# 246 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 247 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 248 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 249 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=2)), poison_4=Cell(x=5, y=3)))
#
# 250 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=2)), poison_4=Cell(x=4, y=3)))
#
# 251 - MazeState(slug_1=Cell(x=0, y=0)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=2)), poison_4=Cell(x=4, y=3)))
#
# 252 - MazeState(slug_1=Cell(x=1, y=1)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=0, y=1)), poison_2=Cell(x=1, y=2)), poison_3=Cell(x=5, y=2)), poison_4=Cell(x=4, y=3)))
#
# 253 - MazeState(slug_1=Cell(x=2, y=0)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=1, y=2)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 254 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=1)), poison_2=None, poison_3=Cell(x=2, y=0)), poison_4=None)
#
# 255 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=3, y=3)), poison_1=Cell(x=2, y=5)), poison_2=Cell(x=1, y=5)), poison_3=Cell(x=3, y=4)), poison_4=Cell(x=2, y=4)))
#
# 256 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=0, y=5)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=0, y=3)))
#
# 257 - MazeState(slug_1=Cell(x=1, y=5)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=0, y=5)), poison_2=Cell(x=1, y=4)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=0, y=3)))
#
# 258 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=2, y=4)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 259 - MazeState(slug_1=Cell(x=1, y=3)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=2, y=4)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 260 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=2, y=4)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 261 - MazeState(slug_1=Cell(x=4, y=4)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=3, y=4)), poison_2=Cell(x=2, y=4)), poison_3=Cell(x=1, y=2)), poison_4=Cell(x=0, y=2)))
#
# 262 - MazeState(slug_1=Cell(x=3, y=5)), slug_2=Cell(x=1, y=1)), poison_1=Cell(x=2, y=4)), poison_2=None, poison_3=Cell(x=0, y=2)), poison_4=None)
#
# 263 - MazeState(slug_1=Cell(x=0, y=2)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 264 - MazeState(slug_1=Cell(x=3, y=3)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=2, y=1)), poison_4=Cell(x=1, y=1)))
#
# 265 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 266 - MazeState(slug_1=Cell(x=0, y=4)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=1, y=1)), poison_4=None)
#
# 267 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=0, y=0)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=1, y=0)), poison_4=Cell(x=1, y=1)))
#
# 268 - MazeState(slug_1=Cell(x=2, y=4)), slug_2=Cell(x=2, y=0)), poison_1=Cell(x=2, y=3)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=1, y=0)), poison_4=Cell(x=1, y=1)))
#
# 269 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 270 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 271 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 272 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 273 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=5)))
#
# 274 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=0, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=5)))
#
# 275 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 276 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=3, y=5)), poison_4=None)
#
# 277 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=1, y=3)), poison_2=Cell(x=0, y=3)), poison_3=Cell(x=5, y=5)), poison_4=Cell(x=4, y=5)))
#
# 278 - MazeState(slug_1=Cell(x=0, y=5)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 279 - MazeState(slug_1=Cell(x=2, y=5)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=0, y=2)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 280 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=5, y=4)))
#
# 281 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=5, y=4)))
#
# 282 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=5, y=4)))
#
# 283 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=5, y=4)))
#
# 284 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=2, y=3)), poison_2=None, poison_3=Cell(x=5, y=4)), poison_4=None)
#
# 285 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=5, y=4)))
#
# 286 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=2, y=3)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=5, y=4)))
#
# 287 - MazeState(slug_1=Cell(x=0, y=3)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 288 - MazeState(slug_1=Cell(x=1, y=4)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=1, y=3)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 289 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=4)))
#
# 290 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=0, y=2)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=4)))
#
# 291 - MazeState(slug_1=Cell(x=3, y=4)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=2, y=4)), poison_2=Cell(x=1, y=3)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=4)))
#
# 292 - MazeState(slug_1=Cell(x=2, y=1)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 293 - MazeState(slug_1=Cell(x=1, y=2)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=1, y=0)), poison_2=None, poison_3=Cell(x=2, y=5)), poison_4=None)
#
# 294 - MazeState(slug_1=Cell(x=4, y=5)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 295 - MazeState(slug_1=Cell(x=4, y=5)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 296 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 297 - MazeState(slug_1=Cell(x=5, y=4)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 298 - MazeState(slug_1=Cell(x=5, y=4)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=4, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=3, y=4)))
#
# 299 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=1, y=4)))
#
# 300 - MazeState(slug_1=Cell(x=4, y=3)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=1, y=3)), poison_4=Cell(x=1, y=4)))
#
# 301 - MazeState(slug_1=Cell(x=4, y=5)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=3, y=4)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 302 - MazeState(slug_1=Cell(x=4, y=5)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=3, y=4)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 303 - MazeState(slug_1=Cell(x=2, y=3)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=3, y=3)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=0, y=4)), poison_4=Cell(x=1, y=4)))
#
# ...
#
# 785 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=7, y=2)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=3)), poison_4=None)
#
# 786 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=3)), poison_4=None)
#
# 787 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=6, y=3)))
#
# 788 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=7, y=3)), poison_4=Cell(x=6, y=4)))
#
# 789 - MazeState(slug_1=Cell(x=6, y=3)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=3)), poison_2=Cell(x=4, y=3)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=6, y=1)))
#
# 790 - MazeState(slug_1=Cell(x=5, y=4)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=5, y=3)), poison_2=Cell(x=4, y=3)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=6, y=1)))
#
# 791 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=6, y=4)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=5, y=2)))
#
# 792 - MazeState(slug_1=Cell(x=6, y=5)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=3, y=4)), poison_2=None, poison_3=Cell(x=5, y=2)), poison_4=None)
#
# 793 - MazeState(slug_1=Cell(x=6, y=5)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=5)), poison_2=Cell(x=3, y=4)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=5, y=2)))
#
# 794 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=6, y=5)))
#
# 795 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=6, y=5)))
#
# 796 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=6, y=5)))
#
# 797 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=6, y=5)))
#
# 798 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=5, y=3)))
#
# 799 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=5, y=3)))
#
# 800 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=5, y=3)))
#
# 801 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=6, y=2)), poison_4=Cell(x=5, y=3)))
#
# 802 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 803 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 804 - MazeState(slug_1=Cell(x=6, y=3)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 805 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 806 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=5, y=3)), poison_4=None)
#
# 807 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=4)))
#
# 808 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=4)))
#
# 809 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=6, y=1)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=4)))
#
# 810 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=4)))
#
# 811 - MazeState(slug_1=Cell(x=6, y=3)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=7, y=3)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=1)), poison_4=Cell(x=4, y=4)))
#
# 812 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=4)))
#
# 813 - MazeState(slug_1=Cell(x=6, y=5)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=4, y=4)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 814 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=4, y=4)), poison_2=None, poison_3=Cell(x=4, y=4)), poison_4=None)
#
# 815 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=6, y=4)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=0, y=2)))
#
# 816 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=3, y=4)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 817 - MazeState(slug_1=Cell(x=7, y=4)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=3, y=4)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 818 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 819 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 820 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 821 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=4)))
#
# 822 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 823 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 824 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=0, y=4)), poison_4=None)
#
# 825 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=6, y=3)), poison_2=None, poison_3=Cell(x=1, y=4)), poison_4=None)
#
# 826 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=3)))
#
# 827 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=3)))
#
# 828 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=3)))
#
# 829 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=3)))
#
# 830 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 831 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 832 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 833 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=6, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=2)))
#
# 834 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=6, y=3)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=2)))
#
# 835 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=5, y=2)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 836 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 837 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=5, y=4)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=6, y=1)), poison_3=Cell(x=5, y=3)), poison_4=Cell(x=4, y=3)))
#
# 838 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=3, y=4)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 839 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=2, y=4)))
#
# 840 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=4, y=5)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=2, y=4)))
#
# 841 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=4, y=3)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=3, y=3)), poison_3=Cell(x=4, y=4)), poison_4=Cell(x=2, y=4)))
#
# 842 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=2, y=5)), poison_1=Cell(x=3, y=3)), poison_2=None, poison_3=Cell(x=2, y=4)), poison_4=None)
#
# 843 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=7, y=4)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=1)), poison_3=Cell(x=6, y=4)), poison_4=Cell(x=5, y=4)))
#
# 844 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=3)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=5, y=4)), poison_4=None)
#
# 845 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=6, y=1)), poison_3=Cell(x=5, y=5)), poison_4=Cell(x=5, y=4)))
#
# 846 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=6, y=5)), poison_1=Cell(x=4, y=0)), poison_2=Cell(x=4, y=1)), poison_3=Cell(x=5, y=5)), poison_4=Cell(x=4, y=5)))
#
# 847 - MazeState(slug_1=Cell(x=6, y=5)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=7, y=4)), poison_2=None, poison_3=Cell(x=4, y=3)), poison_4=None)
#
# 848 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=1, y=4)), poison_1=Cell(x=7, y=1)), poison_2=Cell(x=7, y=2)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=2, y=5)))
#
# 849 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=6, y=3)), poison_2=None, poison_3=Cell(x=2, y=1)), poison_4=None)
#
# 850 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=4, y=4)), poison_3=Cell(x=0, y=0)), poison_4=Cell(x=1, y=3)))
#
# 851 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=1, y=0)), poison_1=Cell(x=4, y=4)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 852 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=4, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=0, y=2)), poison_4=Cell(x=1, y=3)))
#
# 853 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 854 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 855 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=2, y=1)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=1, y=3)))
#
# 856 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=1, y=2)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=1, y=1)), poison_4=Cell(x=1, y=3)))
#
# 857 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 858 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=0, y=5)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 859 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=0, y=3)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=1, y=3)), poison_4=None)
#
# 860 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=2, y=3)), poison_1=Cell(x=6, y=0)), poison_2=Cell(x=5, y=1)), poison_3=Cell(x=2, y=4)), poison_4=Cell(x=1, y=3)))
#
# 861 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=0, y=1)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=1, y=2)), poison_4=None)
#
# 862 - MazeState(slug_1=Cell(x=7, y=0)), slug_2=Cell(x=7, y=2)), poison_1=Cell(x=6, y=1)), poison_2=None, poison_3=Cell(x=6, y=3)), poison_4=None)
#
# 863 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=1)), poison_4=None)
#
# 864 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=4, y=1)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=1)), poison_4=None)
#
# 865 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=5, y=0)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=1)), poison_4=None)
#
# 866 - MazeState(slug_1=Cell(x=5, y=0)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=1)))
#
# 867 - MazeState(slug_1=Cell(x=4, y=1)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=1)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=1)), poison_4=Cell(x=6, y=1)))
#
# 868 - MazeState(slug_1=Cell(x=7, y=2)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=5, y=3)), poison_2=None, poison_3=Cell(x=6, y=2)), poison_4=None)
#
# 869 - MazeState(slug_1=Cell(x=6, y=1)), slug_2=Cell(x=7, y=0)), poison_1=Cell(x=6, y=2)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=6, y=0)), poison_4=Cell(x=5, y=0)))
#
# 870 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=6, y=1)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=7, y=2)), poison_4=Cell(x=7, y=3)))
#
# 871 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=6, y=2)), poison_1=Cell(x=5, y=0)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=2)), poison_4=Cell(x=6, y=3)))
#
# 872 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=7, y=3)), poison_1=Cell(x=5, y=0)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=2)), poison_4=Cell(x=6, y=3)))
#
# 873 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=5, y=0)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=2)), poison_4=Cell(x=6, y=3)))
#
# 874 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=7, y=1)), poison_1=Cell(x=5, y=0)), poison_2=Cell(x=5, y=2)), poison_3=Cell(x=7, y=2)), poison_4=Cell(x=6, y=3)))
#
# 875 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=6, y=4)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=3)), poison_4=None)
#
# 876 - MazeState(slug_1=Cell(x=5, y=1)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=5, y=2)), poison_2=None, poison_3=Cell(x=6, y=3)), poison_4=None)
#
# 877 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=5, y=1)), poison_1=Cell(x=6, y=1)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=6, y=1)), poison_4=Cell(x=6, y=2)))
#
# 878 - MazeState(slug_1=Cell(x=7, y=1)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=6, y=1)), poison_2=Cell(x=6, y=2)), poison_3=Cell(x=6, y=1)), poison_4=Cell(x=6, y=2)))
#
# 879 - MazeState(slug_1=Cell(x=7, y=5)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=7, y=4)), poison_2=Cell(x=6, y=4)), poison_3=Cell(x=7, y=0)), poison_4=Cell(x=7, y=1)))
#
# 880 - MazeState(slug_1=Cell(x=7, y=3)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=7, y=4)), poison_2=Cell(x=6, y=4)), poison_3=Cell(x=7, y=0)), poison_4=Cell(x=7, y=1)))
#
# 881 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=4, y=4)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 882 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 883 - MazeState(slug_1=Cell(x=6, y=0)), slug_2=Cell(x=7, y=5)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=6, y=4)), poison_4=None)
#
# 884 - MazeState(slug_1=Cell(x=4, y=0)), slug_2=Cell(x=6, y=0)), poison_1=Cell(x=5, y=1)), poison_2=None, poison_3=Cell(x=6, y=2)), poison_4=None)
