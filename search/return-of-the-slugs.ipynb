# %%
class Cell:
    def __init__(self, x: int, y: int) -> None:
        self.x = x
        self.y = y

    def __str__(self) -> str:
        return f"Cell(x={self.x}, y={self.y})"

    def __eq__(self, __value: object) -> bool:
        if not isinstance(__value, Cell) or __value is None:
            return False

        return self.x == __value.x and self.y == __value.y

    def __add__(self, __value: "Cell"):
        return Cell(self.x + __value.x, self.y + __value.y)

    def __sub__(self, __value: "Cell"):
        return Cell(self.x - __value.x, self.y - __value.y)

    @property
    def is_within_boundaries(self):
        return 0 <= self.x <= 7 and 0 <= self.y <= 5

# %%
from typing import NamedTuple, Union

POISONOUS_CELL = Union[Cell, None]


class MazeState(NamedTuple):
    slug_1: Cell
    slug_2: Cell
    poison_1: POISONOUS_CELL
    poison_2: POISONOUS_CELL
    poison_3: POISONOUS_CELL
    poison_4: POISONOUS_CELL

    def __str__(self) -> str:
        return f"MazeState(slug_1={self.slug_1}, slug_2={self.slug_2}, poison_1={self.poison_1}, poison_2={self.poison_2}, poison_3={self.poison_3}, poison_4={self.poison_4})"

    def __eq__(self, __value: "MazeState") -> bool:
        return self.slug_1 == __value.slug_1 and self.slug_2 == __value.slug_2

    @staticmethod
    def with_initial_state(s1: Cell, s2: Cell) -> "MazeState":
        return MazeState(s1, s2, None, None, None, None)

    def with_poisonous_cells(self, s1: Cell, s2: Cell, timestep: int) -> "MazeState":
        if timestep != 0 and timestep % 2 == 0:
            return MazeState(
                s1,
                s2,
                poison_1=self.poison_1,
                poison_2=None,
                poison_3=self.poison_3,
                poison_4=None,
            )

        return MazeState(
            s1,
            s2,
            poison_1=self.slug_1,
            poison_2=self.poison_1,
            poison_3=self.slug_2,
            poison_4=self.poison_3,
        )

# %%
class Node:
    def __init__(
        self, state: MazeState, parent: Union["Node", None], action: str
    ) -> None:
        self.state = state
        self.parent = parent
        self.action = action

# %%
from abc import ABC, abstractmethod


class Frontier(ABC):
    @abstractmethod
    def is_empty(self) -> bool:
        pass

    @abstractmethod
    def add_node(self, node: Node) -> None:
        pass

    @abstractmethod
    def remove_node(self) -> Node:
        pass

    @abstractmethod
    def has_state(self, state: MazeState) -> bool:
        pass


class StackFrontier(Frontier):
    def __init__(self) -> None:
        self.frontier: list[Node] = []

    @property
    def is_empty(self) -> bool:
        return len(self.frontier) == 0

    def add_node(self, node: Node) -> None:
        self.frontier.append(node)

    def remove_node(self) -> Node:
        if self.is_empty:
            raise Exception("Empty frontier")
        else:
            return self.frontier.pop()

    def has_state(self, state: MazeState) -> bool:
        return any(state == n.state for n in self.frontier)


class QueueFrontier(StackFrontier):
    def remove_node(self) -> Node:
        if self.is_empty:
            raise Exception("Empty frontier")
        else:
            return self.frontier.pop(0)

# %%
CANDIDATE_ACTION = tuple[str, MazeState]


def create_candidates(state: MazeState, timestep: int):
    slug1, slug2, poison1, _, poison3, _ = state

    candidates: list[CANDIDATE_ACTION] = [
        # They move in the same direction
        (
            "Both slugs moves up",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1),
                slug2 + Cell(0, 1),
                timestep=timestep,
            ),
        ),
        (
            "Both slugs moves down",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1),
                slug2 + Cell(0, -1),
                timestep=timestep,
            ),
        ),
        (
            "Both slugs moves left",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0),
                slug2 + Cell(-1, 0),
                timestep=timestep,
            ),
        ),
        (
            "Both slugs moves right",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0),
                slug2 + Cell(1, 0),
                timestep=timestep,
            ),
        ),
        # They move in opposite directions
        # Slug 1 up
        (
            "Slug 1 moves up, slug 2 moves left",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1),
                slug2 + Cell(-1, 0),
                timestep=timestep,
            ),
        ),
        (
            "Slug 1 moves up, slug 2 moves right",
            state.with_poisonous_cells(
                slug1 + Cell(0, 1),
                slug2 + Cell(1, 0),
                timestep=timestep,
            ),
        ),
        # Slug 1 down
        (
            "Slug 1 moves down, slug 2 moves left",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1),
                slug2 + Cell(-1, 0),
                timestep=timestep,
            ),
        ),
        (
            "Slug 1 moves down, slug 2 moves right",
            state.with_poisonous_cells(
                slug1 + Cell(0, -1),
                slug2 + Cell(1, 0),
                timestep=timestep,
            ),
        ),
        # Slug 1 left
        (
            "Slug 1 moves left, slug 2 moves up",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0),
                slug2 + Cell(0, 1),
                timestep=timestep,
            ),
        ),
        (
            "Slug 1 moves left, slug 2 moves down",
            state.with_poisonous_cells(
                slug1 + Cell(-1, 0),
                slug2 + Cell(0, -1),
                timestep=timestep,
            ),
        ),
        # Slug 1 right
        (
            "Slug 1 moves right, slug 2 moves up",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0),
                slug2 + Cell(0, 1),
                timestep=timestep,
            ),
        ),
        (
            "Slug 1 moves right, slug 2 moves down",
            state.with_poisonous_cells(
                slug1 + Cell(1, 0),
                slug2 + Cell(0, -1),
                timestep=timestep,
            ),
        ),
    ]

    return candidates

# %%
class SlugMaze:
    def __init__(
        self,
        initial_state: MazeState,
        goal_state: MazeState,
        wall: list[Cell],
    ) -> None:
        self.initial_state = initial_state
        self.goal_state = goal_state
        self.wall = wall

        self.solution: Union[list[CANDIDATE_ACTION], None] = None
        self.timestep = 0

    def __str__(self) -> str:
        return f"SlugMaze(initial_state={self.initial_state}, goal_state={self.goal_state}, wall={self.wall}, solution={self.solution})"

    def print_solution(self) -> None:
        if self.solution is None:
            print("No solution")
        else:
            print(f"With {len(self.solution)} steps, we can reach the goal state:\n")
            for action, state in self.solution:
                s1, s2 = state.slug_1, state.slug_2
                print(f"{action} - Slug 1 at {s1} and Slug 2 at {s2}\n")

    def neighbors(self, state: MazeState, previous_action: str, goal: MazeState):
        # goal_slug1, goal_slug2, _, _, _, _ = goal

        candidates: list[CANDIDATE_ACTION] = create_candidates(state, self.timestep)
        self.timestep += 1
        result: list[CANDIDATE_ACTION] = []

        for action, candidate in candidates:
            slug1, slug2, poison1, poison2, poison3, poison4 = candidate
            poisonous_cells = [poison1, poison2, poison3, poison4]

            if (
                slug1 not in self.wall
                and slug2 not in self.wall
                and slug1 not in poisonous_cells
                and slug2 not in poisonous_cells
            ):  # not heading into bad cells
                if (
                    slug1.is_within_boundaries
                    and slug2.is_within_boundaries
                    and action != previous_action
                ):  # ensure we're still on the board
                    result.append((action, candidate))

        return result

    def solve(self, frontier: StackFrontier) -> None:
        self.num_explored = 0

        start = Node(state=self.initial_state, parent=None, action="None")
        frontier.add_node(start)

        self.explored: list[MazeState] = []

        while True:
            if frontier.is_empty:
                raise Exception("No solution")

            node = frontier.remove_node()
            self.num_explored += 1

            print(f"{self.num_explored} - {node.state}\n")

            if node.state == self.goal_state:
                actions = []
                cells = []
                while node.parent is not None:
                    actions.append(node.action)
                    cells.append(node.state)
                    node = node.parent
                actions.reverse()
                cells.reverse()
                self.solution = list(zip(actions, cells))
                return

            self.explored.append(node.state)

            for action, state in self.neighbors(
                node.state, node.action, self.goal_state
            ):
                if state not in self.explored and not frontier.has_state(state):
                    child = Node(state=state, parent=node, action=action)
                    frontier.add_node(child)

# %%
wall: list[Cell] = [Cell(3, 0), Cell(3, 1), Cell(3, 2), Cell(4, 2), Cell(2, 2)]

goal_state = MazeState(
    slug_1=Cell(4, 0),
    slug_2=Cell(6, 0),
    poison_1=None,
    poison_2=None,
    poison_3=None,
    poison_4=None,
)

with_initial_state = MazeState.with_initial_state(s1=Cell(0, 0), s2=Cell(0, 4))
maze = SlugMaze(initial_state=with_initial_state, goal_state=goal_state, wall=wall)
stack_frontier = StackFrontier()
maze.solve(stack_frontier)
# Out:
# 1 - MazeState(slug_1=Cell(x=0, y=0), slug_2=Cell(x=0, y=4), poison_1=None, poison_2=None, poison_3=None, poison_4=None)
#
# 2 - MazeState(slug_1=Cell(x=1, y=0), slug_2=Cell(x=0, y=3), poison_1=Cell(x=0, y=0), poison_2=None, poison_3=Cell(x=0, y=4), poison_4=None)
#
# 3 - MazeState(slug_1=Cell(x=1, y=1), slug_2=Cell(x=1, y=3), poison_1=Cell(x=1, y=0), poison_2=Cell(x=0, y=0), poison_3=Cell(x=0, y=3), poison_4=Cell(x=0, y=4))
#
# 4 - MazeState(slug_1=Cell(x=2, y=1), slug_2=Cell(x=1, y=2), poison_1=Cell(x=1, y=0), poison_2=None, poison_3=Cell(x=0, y=3), poison_4=None)
#
# 5 - MazeState(slug_1=Cell(x=1, y=1), slug_2=Cell(x=1, y=1), poison_1=Cell(x=2, y=1), poison_2=Cell(x=1, y=0), poison_3=Cell(x=1, y=2), poison_4=Cell(x=0, y=3))
#
# 6 - MazeState(slug_1=Cell(x=1, y=0), slug_2=Cell(x=0, y=1), poison_1=Cell(x=2, y=1), poison_2=None, poison_3=Cell(x=1, y=2), poison_4=None)
#
# 7 - MazeState(slug_1=Cell(x=2, y=0), slug_2=Cell(x=0, y=0), poison_1=Cell(x=1, y=0), poison_2=Cell(x=2, y=1), poison_3=Cell(x=0, y=1), poison_4=Cell(x=1, y=2))
#
# 8 - MazeState(slug_1=Cell(x=0, y=0), slug_2=Cell(x=0, y=0), poison_1=Cell(x=1, y=0), poison_2=Cell(x=2, y=1), poison_3=Cell(x=0, y=1), poison_4=Cell(x=1, y=2))
#
# 9 - MazeState(slug_1=Cell(x=0, y=0), slug_2=Cell(x=0, y=2), poison_1=Cell(x=1, y=0), poison_2=Cell(x=2, y=1), poison_3=Cell(x=0, y=1), poison_4=Cell(x=1, y=2))
#
# 10 - MazeState(slug_1=Cell(x=0, y=1), slug_2=Cell(x=0, y=1), poison_1=Cell(x=2, y=1), poison_2=None, poison_3=Cell(x=1, y=2), poison_4=None)
#
# 11 - MazeState(slug_1=Cell(x=1, y=1), slug_2=Cell(x=0, y=0), poison_1=Cell(x=0, y=1), poison_2=Cell(x=2, y=1), poison_3=Cell(x=0, y=1), poison_4=Cell(x=1, y=2))
#
# 12 - MazeState(slug_1=Cell(x=1, y=2), slug_2=Cell(x=1, y=0), poison_1=Cell(x=0, y=1), poison_2=None, poison_3=Cell(x=0, y=1), poison_4=None)
#
# 13 - MazeState(slug_1=Cell(x=1, y=1), slug_2=Cell(x=2, y=0), poison_1=Cell(x=1, y=2), poison_2=Cell(x=0, y=1), poison_3=Cell(x=1, y=0), poison_4=Cell(x=0, y=1))
#
# 14 - MazeState(slug_1=Cell(x=2, y=1), slug_2=Cell(x=2, y=1), poison_1=Cell(x=1, y=2), poison_2=None, poison_3=Cell(x=1, y=0), poison_4=None)
#
# 15 - MazeState(slug_1=Cell(x=2, y=0), slug_2=Cell(x=2, y=0), poison_1=Cell(x=2, y=1), poison_2=Cell(x=1, y=2), poison_3=Cell(x=2, y=1), poison_4=Cell(x=1, y=0))
#
# 16 - MazeState(slug_1=Cell(x=0, y=1), slug_2=Cell(x=2, y=1), poison_1=Cell(x=1, y=2), poison_2=None, poison_3=Cell(x=1, y=0), poison_4=None)
#
# 17 - MazeState(slug_1=Cell(x=0, y=0), slug_2=Cell(x=2, y=0), poison_1=Cell(x=0, y=1), poison_2=Cell(x=1, y=2), poison_3=Cell(x=2, y=1), poison_4=Cell(x=1, y=0))
#
# 18 - MazeState(slug_1=Cell(x=1, y=3), slug_2=Cell(x=0, y=0), poison_1=Cell(x=1, y=2), poison_2=Cell(x=0, y=1), poison_3=Cell(x=1, y=0), poison_4=Cell(x=0, y=1))
#
# 19 - MazeState(slug_1=Cell(x=2, y=3), slug_2=Cell(x=0, y=1), poison_1=Cell(x=1, y=3), poison_2=Cell(x=1, y=2), poison_3=Cell(x=0, y=0), poison_4=Cell(x=1, y=0))
#
# 20 - MazeState(slug_1=Cell(x=2, y=4), slug_2=Cell(x=1, y=1), poison_1=Cell(x=1, y=3), poison_2=None, poison_3=Cell(x=0, y=0), poison_4=None)
#
# 21 - MazeState(slug_1=Cell(x=3, y=4), slug_2=Cell(x=1, y=0), poison_1=Cell(x=2, y=4), poison_2=Cell(x=1, y=3), poison_3=Cell(x=1, y=1), poison_4=Cell(x=0, y=0))
#
# 22 - MazeState(slug_1=Cell(x=3, y=3), slug_2=Cell(x=2, y=0), poison_1=Cell(x=2, y=4), poison_2=None, poison_3=Cell(x=1, y=1), poison_4=None)
#
# 23 - MazeState(slug_1=Cell(x=4, y=3), slug_2=Cell(x=2, y=1), poison_1=Cell(x=3, y=3), poison_2=Cell(x=2, y=4), poison_3=Cell(x=2, y=0), poison_4=Cell(x=1, y=1))
#
# 24 - MazeState(slug_1=Cell(x=4, y=4), slug_2=Cell(x=1, y=1), poison_1=Cell(x=3, y=3), poison_2=None, poison_3=Cell(x=2, y=0), poison_4=None)
#
# 25 - MazeState(slug_1=Cell(x=5, y=4), slug_2=Cell(x=1, y=0), poison_1=Cell(x=4, y=4), poison_2=Cell(x=3, y=3), poison_3=Cell(x=1, y=1), poison_4=Cell(x=2, y=0))
#
# 26 - MazeState(slug_1=Cell(x=5, y=3), slug_2=Cell(x=2, y=0), poison_1=Cell(x=4, y=4), poison_2=None, poison_3=Cell(x=1, y=1), poison_4=None)
#
# 27 - MazeState(slug_1=Cell(x=6, y=3), slug_2=Cell(x=2, y=1), poison_1=Cell(x=5, y=3), poison_2=Cell(x=4, y=4), poison_3=Cell(x=2, y=0), poison_4=Cell(x=1, y=1))
#
# 28 - MazeState(slug_1=Cell(x=6, y=2), slug_2=Cell(x=1, y=1), poison_1=Cell(x=5, y=3), poison_2=None, poison_3=Cell(x=2, y=0), poison_4=None)
#
# 29 - MazeState(slug_1=Cell(x=7, y=2), slug_2=Cell(x=1, y=0), poison_1=Cell(x=6, y=2), poison_2=Cell(x=5, y=3), poison_3=Cell(x=1, y=1), poison_4=Cell(x=2, y=0))
#
# 30 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=2, y=0), poison_1=Cell(x=6, y=2), poison_2=None, poison_3=Cell(x=1, y=1), poison_4=None)
#
# 31 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=1, y=0), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=2), poison_3=Cell(x=2, y=0), poison_4=Cell(x=1, y=1))
#
# 32 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=1, y=1), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=2, y=0), poison_4=None)
#
# 33 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=1, y=2), poison_1=Cell(x=6, y=0), poison_2=Cell(x=7, y=1), poison_3=Cell(x=1, y=1), poison_4=Cell(x=2, y=0))
#
# 34 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=0, y=2), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=1, y=1), poison_4=None)
#
# 35 - MazeState(slug_1=Cell(x=6, y=1), slug_2=Cell(x=0, y=3), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=0, y=2), poison_4=Cell(x=1, y=1))
#
# 36 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=1, y=3), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=0, y=2), poison_4=None)
#
# 37 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=1, y=4), poison_1=Cell(x=6, y=0), poison_2=Cell(x=7, y=1), poison_3=Cell(x=1, y=3), poison_4=Cell(x=0, y=2))
#
# 38 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=2, y=4), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=1, y=3), poison_4=None)
#
# 39 - MazeState(slug_1=Cell(x=6, y=1), slug_2=Cell(x=2, y=5), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=2, y=4), poison_4=Cell(x=1, y=3))
#
# 40 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=3, y=5), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=2, y=4), poison_4=None)
#
# 41 - MazeState(slug_1=Cell(x=5, y=0), slug_2=Cell(x=3, y=4), poison_1=Cell(x=6, y=0), poison_2=Cell(x=7, y=1), poison_3=Cell(x=3, y=5), poison_4=Cell(x=2, y=4))
#
# 42 - MazeState(slug_1=Cell(x=5, y=1), slug_2=Cell(x=4, y=4), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=3, y=5), poison_4=None)
#
# 43 - MazeState(slug_1=Cell(x=6, y=1), slug_2=Cell(x=4, y=3), poison_1=Cell(x=5, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=4, y=4), poison_4=Cell(x=3, y=5))
#
# 44 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=5, y=3), poison_1=Cell(x=5, y=1), poison_2=None, poison_3=Cell(x=4, y=4), poison_4=None)
#
# 45 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=5, y=2), poison_1=Cell(x=6, y=0), poison_2=Cell(x=5, y=1), poison_3=Cell(x=5, y=3), poison_4=Cell(x=4, y=4))
#
# 46 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=6, y=2), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=5, y=3), poison_4=None)
#
# 47 - MazeState(slug_1=Cell(x=6, y=1), slug_2=Cell(x=6, y=1), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=6, y=2), poison_4=Cell(x=5, y=3))
#
# 48 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=5, y=1), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=6, y=2), poison_4=None)
#
# 49 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=5, y=0), poison_1=Cell(x=6, y=0), poison_2=Cell(x=7, y=1), poison_3=Cell(x=5, y=1), poison_4=Cell(x=6, y=2))
#
# 50 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=4, y=0), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=5, y=1), poison_4=None)
#
# 51 - MazeState(slug_1=Cell(x=7, y=2), slug_2=Cell(x=5, y=0), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=4, y=0), poison_4=Cell(x=5, y=1))
#
# 52 - MazeState(slug_1=Cell(x=6, y=2), slug_2=Cell(x=5, y=1), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=4, y=0), poison_4=None)
#
# 53 - MazeState(slug_1=Cell(x=5, y=2), slug_2=Cell(x=5, y=0), poison_1=Cell(x=6, y=2), poison_2=Cell(x=7, y=1), poison_3=Cell(x=5, y=1), poison_4=Cell(x=4, y=0))
#
# 54 - MazeState(slug_1=Cell(x=5, y=3), slug_2=Cell(x=6, y=0), poison_1=Cell(x=6, y=2), poison_2=None, poison_3=Cell(x=5, y=1), poison_4=None)
#
# 55 - MazeState(slug_1=Cell(x=4, y=3), slug_2=Cell(x=6, y=1), poison_1=Cell(x=5, y=3), poison_2=Cell(x=6, y=2), poison_3=Cell(x=6, y=0), poison_4=Cell(x=5, y=1))
#
# 56 - MazeState(slug_1=Cell(x=4, y=4), slug_2=Cell(x=7, y=1), poison_1=Cell(x=5, y=3), poison_2=None, poison_3=Cell(x=6, y=0), poison_4=None)
#
# 57 - MazeState(slug_1=Cell(x=5, y=4), slug_2=Cell(x=7, y=0), poison_1=Cell(x=4, y=4), poison_2=Cell(x=5, y=3), poison_3=Cell(x=7, y=1), poison_4=Cell(x=6, y=0))
#
# 58 - MazeState(slug_1=Cell(x=5, y=5), slug_2=Cell(x=6, y=0), poison_1=Cell(x=4, y=4), poison_2=None, poison_3=Cell(x=7, y=1), poison_4=None)
#
# 59 - MazeState(slug_1=Cell(x=6, y=5), slug_2=Cell(x=6, y=1), poison_1=Cell(x=5, y=5), poison_2=Cell(x=4, y=4), poison_3=Cell(x=6, y=0), poison_4=Cell(x=7, y=1))
#
# 60 - MazeState(slug_1=Cell(x=6, y=4), slug_2=Cell(x=7, y=1), poison_1=Cell(x=5, y=5), poison_2=None, poison_3=Cell(x=6, y=0), poison_4=None)
#
# 61 - MazeState(slug_1=Cell(x=7, y=4), slug_2=Cell(x=7, y=0), poison_1=Cell(x=6, y=4), poison_2=Cell(x=5, y=5), poison_3=Cell(x=7, y=1), poison_4=Cell(x=6, y=0))
#
# 62 - MazeState(slug_1=Cell(x=7, y=3), slug_2=Cell(x=6, y=0), poison_1=Cell(x=6, y=4), poison_2=None, poison_3=Cell(x=7, y=1), poison_4=None)
#
# 63 - MazeState(slug_1=Cell(x=7, y=2), slug_2=Cell(x=7, y=0), poison_1=Cell(x=7, y=3), poison_2=Cell(x=6, y=4), poison_3=Cell(x=6, y=0), poison_4=Cell(x=7, y=1))
#
# 64 - MazeState(slug_1=Cell(x=6, y=2), slug_2=Cell(x=7, y=1), poison_1=Cell(x=7, y=3), poison_2=None, poison_3=Cell(x=6, y=0), poison_4=None)
#
# 65 - MazeState(slug_1=Cell(x=7, y=2), slug_2=Cell(x=7, y=2), poison_1=Cell(x=6, y=2), poison_2=Cell(x=7, y=3), poison_3=Cell(x=7, y=1), poison_4=Cell(x=6, y=0))
#
# 66 - MazeState(slug_1=Cell(x=7, y=3), slug_2=Cell(x=7, y=3), poison_1=Cell(x=6, y=2), poison_2=None, poison_3=Cell(x=7, y=1), poison_4=None)
#
# 67 - MazeState(slug_1=Cell(x=6, y=3), slug_2=Cell(x=7, y=4), poison_1=Cell(x=7, y=3), poison_2=Cell(x=6, y=2), poison_3=Cell(x=7, y=3), poison_4=Cell(x=7, y=1))
#
# 68 - MazeState(slug_1=Cell(x=6, y=2), slug_2=Cell(x=6, y=4), poison_1=Cell(x=7, y=3), poison_2=None, poison_3=Cell(x=7, y=3), poison_4=None)
#
# 69 - MazeState(slug_1=Cell(x=7, y=2), slug_2=Cell(x=6, y=5), poison_1=Cell(x=6, y=2), poison_2=Cell(x=7, y=3), poison_3=Cell(x=6, y=4), poison_4=Cell(x=7, y=3))
#
# 70 - MazeState(slug_1=Cell(x=7, y=1), slug_2=Cell(x=7, y=5), poison_1=Cell(x=6, y=2), poison_2=None, poison_3=Cell(x=6, y=4), poison_4=None)
#
# 71 - MazeState(slug_1=Cell(x=7, y=0), slug_2=Cell(x=6, y=5), poison_1=Cell(x=7, y=1), poison_2=Cell(x=6, y=2), poison_3=Cell(x=7, y=5), poison_4=Cell(x=6, y=4))
#
# 72 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=6, y=4), poison_1=Cell(x=7, y=1), poison_2=None, poison_3=Cell(x=7, y=5), poison_4=None)
#
# 73 - MazeState(slug_1=Cell(x=5, y=0), slug_2=Cell(x=6, y=5), poison_1=Cell(x=6, y=0), poison_2=Cell(x=7, y=1), poison_3=Cell(x=6, y=4), poison_4=Cell(x=7, y=5))
#
# 74 - MazeState(slug_1=Cell(x=5, y=1), slug_2=Cell(x=7, y=5), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=6, y=4), poison_4=None)
#
# 75 - MazeState(slug_1=Cell(x=4, y=1), slug_2=Cell(x=7, y=4), poison_1=Cell(x=5, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=7, y=5), poison_4=Cell(x=6, y=4))
#
# 76 - MazeState(slug_1=Cell(x=4, y=0), slug_2=Cell(x=6, y=4), poison_1=Cell(x=5, y=1), poison_2=None, poison_3=Cell(x=7, y=5), poison_4=None)
#
# 77 - MazeState(slug_1=Cell(x=5, y=0), slug_2=Cell(x=6, y=3), poison_1=Cell(x=4, y=0), poison_2=Cell(x=5, y=1), poison_3=Cell(x=6, y=4), poison_4=Cell(x=7, y=5))
#
# 78 - MazeState(slug_1=Cell(x=5, y=1), slug_2=Cell(x=7, y=3), poison_1=Cell(x=4, y=0), poison_2=None, poison_3=Cell(x=6, y=4), poison_4=None)
#
# 79 - MazeState(slug_1=Cell(x=6, y=1), slug_2=Cell(x=7, y=2), poison_1=Cell(x=5, y=1), poison_2=Cell(x=4, y=0), poison_3=Cell(x=7, y=3), poison_4=Cell(x=6, y=4))
#
# 80 - MazeState(slug_1=Cell(x=6, y=0), slug_2=Cell(x=6, y=2), poison_1=Cell(x=5, y=1), poison_2=None, poison_3=Cell(x=7, y=3), poison_4=None)
#
# 81 - MazeState(slug_1=Cell(x=5, y=0), slug_2=Cell(x=6, y=1), poison_1=Cell(x=6, y=0), poison_2=Cell(x=5, y=1), poison_3=Cell(x=6, y=2), poison_4=Cell(x=7, y=3))
#
# 82 - MazeState(slug_1=Cell(x=5, y=1), slug_2=Cell(x=7, y=1), poison_1=Cell(x=6, y=0), poison_2=None, poison_3=Cell(x=6, y=2), poison_4=None)
#
# 83 - MazeState(slug_1=Cell(x=4, y=1), slug_2=Cell(x=7, y=0), poison_1=Cell(x=5, y=1), poison_2=Cell(x=6, y=0), poison_3=Cell(x=7, y=1), poison_4=Cell(x=6, y=2))
#
# 84 - MazeState(slug_1=Cell(x=4, y=0), slug_2=Cell(x=6, y=0), poison_1=Cell(x=5, y=1), poison_2=None, poison_3=Cell(x=7, y=1), poison_4=None)

# %%
maze.print_solution()
# Out:
# With 74 steps, we can reach the goal state:
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=1, y=0) and Slug 2 at Cell(x=0, y=3)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=1, y=1) and Slug 2 at Cell(x=1, y=3)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=2, y=1) and Slug 2 at Cell(x=1, y=2)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=1, y=1) and Slug 2 at Cell(x=1, y=1)
#
# Both slugs moves left - Slug 1 at Cell(x=0, y=1) and Slug 2 at Cell(x=0, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=1, y=1) and Slug 2 at Cell(x=0, y=0)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=1, y=2) and Slug 2 at Cell(x=1, y=0)
#
# Slug 1 moves up, slug 2 moves left - Slug 1 at Cell(x=1, y=3) and Slug 2 at Cell(x=0, y=0)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=2, y=3) and Slug 2 at Cell(x=0, y=1)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=2, y=4) and Slug 2 at Cell(x=1, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=3, y=4) and Slug 2 at Cell(x=1, y=0)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=3, y=3) and Slug 2 at Cell(x=2, y=0)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=4, y=3) and Slug 2 at Cell(x=2, y=1)
#
# Slug 1 moves up, slug 2 moves left - Slug 1 at Cell(x=4, y=4) and Slug 2 at Cell(x=1, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=5, y=4) and Slug 2 at Cell(x=1, y=0)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=5, y=3) and Slug 2 at Cell(x=2, y=0)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=6, y=3) and Slug 2 at Cell(x=2, y=1)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=6, y=2) and Slug 2 at Cell(x=1, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=7, y=2) and Slug 2 at Cell(x=1, y=0)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=2, y=0)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=1, y=0)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=1, y=1)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=1, y=2)
#
# Slug 1 moves up, slug 2 moves left - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=0, y=2)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=1) and Slug 2 at Cell(x=0, y=3)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=1, y=3)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=1, y=4)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=2, y=4)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=1) and Slug 2 at Cell(x=2, y=5)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=3, y=5)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=5, y=0) and Slug 2 at Cell(x=3, y=4)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=5, y=1) and Slug 2 at Cell(x=4, y=4)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=6, y=1) and Slug 2 at Cell(x=4, y=3)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=5, y=3)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=5, y=2)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=6, y=2)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=6, y=1) and Slug 2 at Cell(x=6, y=1)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=5, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=5, y=0)
#
# Slug 1 moves up, slug 2 moves left - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=4, y=0)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=7, y=2) and Slug 2 at Cell(x=5, y=0)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=2) and Slug 2 at Cell(x=5, y=1)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=5, y=2) and Slug 2 at Cell(x=5, y=0)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=5, y=3) and Slug 2 at Cell(x=6, y=0)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=4, y=3) and Slug 2 at Cell(x=6, y=1)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=4, y=4) and Slug 2 at Cell(x=7, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=5, y=4) and Slug 2 at Cell(x=7, y=0)
#
# Slug 1 moves up, slug 2 moves left - Slug 1 at Cell(x=5, y=5) and Slug 2 at Cell(x=6, y=0)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=6, y=5) and Slug 2 at Cell(x=6, y=1)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=6, y=4) and Slug 2 at Cell(x=7, y=1)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=7, y=4) and Slug 2 at Cell(x=7, y=0)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=7, y=3) and Slug 2 at Cell(x=6, y=0)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=7, y=2) and Slug 2 at Cell(x=7, y=0)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=2) and Slug 2 at Cell(x=7, y=1)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=7, y=2) and Slug 2 at Cell(x=7, y=2)
#
# Both slugs moves up - Slug 1 at Cell(x=7, y=3) and Slug 2 at Cell(x=7, y=3)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=6, y=3) and Slug 2 at Cell(x=7, y=4)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=6, y=2) and Slug 2 at Cell(x=6, y=4)
#
# Slug 1 moves right, slug 2 moves up - Slug 1 at Cell(x=7, y=2) and Slug 2 at Cell(x=6, y=5)
#
# Slug 1 moves down, slug 2 moves right - Slug 1 at Cell(x=7, y=1) and Slug 2 at Cell(x=7, y=5)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=7, y=0) and Slug 2 at Cell(x=6, y=5)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=6, y=4)
#
# Slug 1 moves left, slug 2 moves up - Slug 1 at Cell(x=5, y=0) and Slug 2 at Cell(x=6, y=5)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=5, y=1) and Slug 2 at Cell(x=7, y=5)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=4, y=1) and Slug 2 at Cell(x=7, y=4)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=4, y=0) and Slug 2 at Cell(x=6, y=4)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=5, y=0) and Slug 2 at Cell(x=6, y=3)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=5, y=1) and Slug 2 at Cell(x=7, y=3)
#
# Slug 1 moves right, slug 2 moves down - Slug 1 at Cell(x=6, y=1) and Slug 2 at Cell(x=7, y=2)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=6, y=0) and Slug 2 at Cell(x=6, y=2)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=5, y=0) and Slug 2 at Cell(x=6, y=1)
#
# Slug 1 moves up, slug 2 moves right - Slug 1 at Cell(x=5, y=1) and Slug 2 at Cell(x=7, y=1)
#
# Slug 1 moves left, slug 2 moves down - Slug 1 at Cell(x=4, y=1) and Slug 2 at Cell(x=7, y=0)
#
# Slug 1 moves down, slug 2 moves left - Slug 1 at Cell(x=4, y=0) and Slug 2 at Cell(x=6, y=0)
